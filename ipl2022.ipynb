# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_html("https://stats.espncricinfo.com/ci/engine/records/bowling/most_wickets_career.html?id=14452;type=tournament")

# %%
for idx,table in enumerate(df):
    print('*'*12)
    print(idx)
    print(table)
# Out:
# ************
# 0
#                            Player                            Mat  \
# 0                       YS Chahal                             17
# 1              (Rajasthan Royals)             (Rajasthan Royals)
# 2                    PWH de Silva                             16
# 3   (Royal Challengers Bangalore)  (Royal Challengers Bangalore)
# 4                        K Rabada                             13
# ..                            ...                            ...
# 91        (Kolkata Knight Riders)        (Kolkata Knight Riders)
# 92                      AS Joseph                              9
# 93               (Gujarat Titans)               (Gujarat Titans)
# 94                       M Jansen                              8
# 95          (Sunrisers Hyderabad)          (Sunrisers Hyderabad)
#
#                              Inns                          Overs  \
# 0                              17                           68.0
# ...

# %%
bowler=df[0]

# %%
bowler
# Out:
#                            Player                            Mat  \
# 0                       YS Chahal                             17
# 1              (Rajasthan Royals)             (Rajasthan Royals)
# 2                    PWH de Silva                             16
# 3   (Royal Challengers Bangalore)  (Royal Challengers Bangalore)
# 4                        K Rabada                             13
# ..                            ...                            ...
# 91        (Kolkata Knight Riders)        (Kolkata Knight Riders)
# 92                      AS Joseph                              9
# 93               (Gujarat Titans)               (Gujarat Titans)
# 94                       M Jansen                              8
# 95          (Sunrisers Hyderabad)          (Sunrisers Hyderabad)
#
#                              Inns                          Overs  \
# 0                              17                           68.0
# ...

# %%
c=bowler[1:96:2]
bowling_figure=bowler[0:96:2]

# %%
 bowling_figure['franchise']=pd.DataFrame(c['Player'])

# %%
bowling_figure
# Out:
#                Player Mat Inns Overs Mdns Runs Wkts   BBI    Ave   Econ    SR  \
# 0           YS Chahal  17   17  68.0    0  527   27  5/40  19.51   7.75  15.1
# 2        PWH de Silva  16   16  57.0    1  430   26  5/18  16.53   7.54  13.1
# 4            K Rabada  13   13  48.0    0  406   23  4/33  17.65   8.45  12.5
# 6         Umran Malik  14   14  49.1    1  444   22  5/25  20.18   9.03  13.4
# 8       Kuldeep Yadav  14   14  49.4    0  419   21  4/14  19.95   8.43  14.1
# 10       JR Hazlewood  12   12  46.3    1  377   20  4/25  18.85   8.10  13.9
# 12     Mohammed Shami  16   16  61.0    0  488   20  3/25  24.40   8.00  18.3
# 14           HV Patel  15   15  53.3    2  410   19  4/34  21.57   7.66  16.8
# 16        Rashid Khan  16   16  63.5    0  421   19  4/24  22.15   6.59  20.1
# 18  M Prasidh Krishna  17   17  66.3    3  551   19  3/22  29.00   8.28  21.0
# 20        T Natarajan  11   11  43.0    0  406   18  3/10  22.55   9.44  14.3
# ...

# %%
bo=pd.DataFrame(c['Player'])

# %%
bowlers=pd.concat([bowl_stats,bowl_stats1],axis=1)

# %%
bowling_figure['ch']=bo.Player

# %%
bowl_stats=bowling_figure.reset_index()

# %%
bowl_stats1=bo.reset_index()

# %%
bowlers.columns
# Out:
# Index(['index', 'Player', 'Mat', 'Inns', 'Overs', 'Mdns', 'Runs', 'Wkts',
#        'BBI', 'Ave', 'Econ', 'SR', '4', '5', 'Team', 'franchise', 'ch',
#        'index', 'Player'],
#       dtype='object')

# %%
bowl_stats=bowlers[[ 'Player', 'Mat', 'Inns', 'Overs', 'Mdns', 'Runs', 'Wkts',
       'BBI', 'Ave', 'Econ', 'SR', '4', '5']]

# %%
bowl_stats.columns
# Out:
# Index(['Player', 'Player', 'Mat', 'Inns', 'Overs', 'Mdns', 'Runs', 'Wkts',
#        'BBI', 'Ave', 'Econ', 'SR', '4', '5'],
#       dtype='object')

# %%
bowl_stats[['Player',  'Mat', 'Inns', 'Overs', 'Mdns', 'Runs', 'Wkts',
       'BBI', 'Ave', 'Econ', 'SR', '4', '5']]
# Out:
#                Player                         Player Mat Inns Overs Mdns Runs  \
# 0           YS Chahal             (Rajasthan Royals)  17   17  68.0    0  527
# 1        PWH de Silva  (Royal Challengers Bangalore)  16   16  57.0    1  430
# 2            K Rabada                 (Punjab Kings)  13   13  48.0    0  406
# 3         Umran Malik          (Sunrisers Hyderabad)  14   14  49.1    1  444
# 4       Kuldeep Yadav               (Delhi Capitals)  14   14  49.4    0  419
# 5        JR Hazlewood  (Royal Challengers Bangalore)  12   12  46.3    1  377
# 6      Mohammed Shami               (Gujarat Titans)  16   16  61.0    0  488
# 7            HV Patel  (Royal Challengers Bangalore)  15   15  53.3    2  410
# 8         Rashid Khan               (Gujarat Titans)  16   16  63.5    0  421
# 9   M Prasidh Krishna             (Rajasthan Royals)  17   17  66.3    3  551
# 10        T Natarajan          (Sunrisers Hyderabad)  11   11  43.0    0  406
# ...

# %%
bowl_stats.to_csv(r'C:\Data\bowler_stats.csv')

# %%
bf=pd.read_html("https://stats.espncricinfo.com/ci/engine/records/batting/most_runs_career.html?id=14452;type=tournament")

# %%
bat=bf[0]
bat
# Out:
#                     Player                     Mat                    Inns  \
# 0               JC Buttler                      17                      17
# 1       (Rajasthan Royals)      (Rajasthan Royals)      (Rajasthan Royals)
# 2                 KL Rahul                      15                      15
# 3   (Lucknow Super Giants)  (Lucknow Super Giants)  (Lucknow Super Giants)
# 4                Q de Kock                      15                      15
# ..                     ...                     ...                     ...
# 95          (Punjab Kings)          (Punjab Kings)          (Punjab Kings)
# 96              MA Agarwal                      13                      12
# 97          (Punjab Kings)          (Punjab Kings)          (Punjab Kings)
# 98                R Ashwin                      17                      12
# 99      (Rajasthan Royals)      (Rajasthan Royals)      (Rajasthan Royals)
#
# ...

# %%
bat1=bat[0:100:2]
bat2=bat[1:100:2]

# %%
team=pd.DataFrame(bat2['Mat'])

# %%
franchise=team.reset_index()

# %%
main=bat1.reset_index()

# %%
main
# Out:
#     index           Player Mat Inns  NO Runs    HS    Ave   BF      SR 100 50  \
# 0       0       JC Buttler  17   17   2  863   116  57.53  579  149.05   4  4
# 1       2         KL Rahul  15   15   3  616  103*  51.33  455  135.38   2  4
# 2       4        Q de Kock  15   15   1  508  140*  36.28  341  148.97   1  3
# 3       6        HH Pandya  15   15   4  487   87*  44.27  371  131.26   0  4
# 4       8     Shubman Gill  16   16   2  483    96  34.50  365  132.32   0  4
# 5      10        DA Miller  16   16   9  481   94*  68.71  337  142.72   0  2
# 6      12     F du Plessis  16   16   1  468    96  31.20  367  127.52   0  3
# 7      14         S Dhawan  14   14   2  460   88*  38.33  375  122.66   0  3
# 8      16        SV Samson  17   17   1  458    55  28.62  312  146.79   0  2
# 9      18         DJ Hooda  15   14   0  451    59  32.21  330  136.66   0  4
# 10     20   LS Livingstone  14   14   2  437    70  36.41  240  182.08   0  4
# ...

# %%
batters=pd.concat([main,franchise],axis=1)

# %%
batters.columns
# Out:
# Index(['index', 'Player', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0', '4s', '6s', 'index', 'Mat'],
#       dtype='object')

# %%
batsman=batters[['index', 'Player', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
       '100', '50', '0', '4s', '6s', 'index']]

# %%
batsman.to_csv(r'C:\Data\batsman_stats.csv')

# %%
batsman
# Out:
#     index  index           Player Mat                            Mat Inns  NO  \
# 0       0      1       JC Buttler  17             (Rajasthan Royals)   17   2
# 1       2      3         KL Rahul  15         (Lucknow Super Giants)   15   3
# 2       4      5        Q de Kock  15         (Lucknow Super Giants)   15   1
# 3       6      7        HH Pandya  15               (Gujarat Titans)   15   4
# 4       8      9     Shubman Gill  16               (Gujarat Titans)   16   2
# 5      10     11        DA Miller  16               (Gujarat Titans)   16   9
# 6      12     13     F du Plessis  16  (Royal Challengers Bangalore)   16   1
# 7      14     15         S Dhawan  14                 (Punjab Kings)   14   2
# 8      16     17        SV Samson  17             (Rajasthan Royals)   17   1
# 9      18     19         DJ Hooda  15         (Lucknow Super Giants)   14   0
# 10     20     21   LS Livingstone  14                 (Punjab Kings)   14   2
# ...
